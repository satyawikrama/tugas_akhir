# %%
import os
import json
import joblib
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    f1_score,
    precision_score,
    recall_score,
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

# %%
# =========================================================
# 1. LOAD DATA
# =========================================================
train_df = pd.read_csv("train_indonesia.csv")
test_df = pd.read_csv("test_indonesia.csv")

possible_labels = [
"kepedulian", "menyakiti",
    "keadilan", "kecurangan",
    "loyalitas", "pengkhianatan",
    "otoritas", "pembangkangan",
    "kesucian", "kemerosotan",
    "kebebasan", "penindasan"
]

# pastikan semua label ada di dataframe
for lab in possible_labels:
    if lab not in train_df.columns:
        raise ValueError(f"Label '{lab}' tidak ditemukan di train_df")
    if lab not in test_df.columns:
        raise ValueError(f"Label '{lab}' tidak ditemukan di test_df")

# teks
X_train_text = train_df["sentence"].astype(str)
X_test_text = test_df["sentence"].astype(str)

# %%
# =========================================================
# 2. TF-IDF VECTORIZATION
# =========================================================
vectorizer = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)

X_train = vectorizer.fit_transform(X_train_text)
X_test = vectorizer.transform(X_test_text)

print("Shape X_train:", X_train.shape)
print("Shape X_test :", X_test.shape)
# Out:
# Shape X_train: (18598, 10000)
# Shape X_test : (4650, 10000)

# %%
# =========================================================
# 3. SIAPKAN FOLDER SIMPAN
# =========================================================
from google.colab import drive
drive.mount('/content/drive')

BASE_DIR = "/content/drive/MyDrive/ML_MoralClassifier/LR_indonesia"
os.makedirs(BASE_DIR, exist_ok=True)

print("Folder penyimpanan:", BASE_DIR)

# simpan vectorizer sekali saja
joblib.dump(vectorizer, os.path.join(BASE_DIR, "tfidf_vectorizer.pkl"))
# Out:
# Mounted at /content/drive
# Folder penyimpanan: /content/drive/MyDrive/ML_MoralClassifier/LR_indonesia
# ['/content/drive/MyDrive/ML_MoralClassifier/LR_indonesia/tfidf_vectorizer.pkl']

# %%
# =========================================================
# 4. TRAINING PER LABEL
# =========================================================
summary_rows = []
threshold_dict = {}
predictions = []

# inisialisasi dataframe prediksi
for i in range(len(test_df)):
    predictions.append({
        "sentence": test_df.iloc[i]["sentence"]
    })

for lab in possible_labels:
    print(f"\n{'='*60}")
    print(f"Processing label: {lab}")

    y_train = train_df[lab].astype(int).values
    y_test = test_df[lab].astype(int).values

    # model
    model = LogisticRegression(
        class_weight="balanced",
        max_iter=2000,
        random_state=42
    )

    # training
    model.fit(X_train, y_train)

    # probabilitas kelas positif
    y_prob = model.predict_proba(X_test)[:, 1]

    # threshold tuning
    best_f1 = -1
    best_th = 0.5
    best_pred = None

    for th in np.arange(0.05, 1.00, 0.05):
        temp_pred = (y_prob >= th).astype(int)
        temp_f1 = f1_score(y_test, temp_pred, average="binary", zero_division=0)

        if temp_f1 > best_f1:
            best_f1 = temp_f1
            best_th = float(th)
            best_pred = temp_pred.copy()

    # metrik final pakai best threshold
    precision = precision_score(y_test, best_pred, average="binary", zero_division=0)
    recall = recall_score(y_test, best_pred, average="binary", zero_division=0)
    acc = accuracy_score(y_test, best_pred)

    # confusion matrix
    cm = confusion_matrix(y_test, best_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    disp.plot(cmap="Blues")
    plt.title(f"Confusion Matrix - {lab}")
    plt.show()

    print(f"Best threshold : {best_th:.2f}")
    print(f"F1 Score       : {best_f1:.4f}")
    print(f"Precision      : {precision:.4f}")
    print(f"Recall         : {recall:.4f}")
    print(f"Accuracy       : {acc:.4f}")

    print("\nConfusion Matrix:")
    print(cm)

    print("\nTN =", tn)
    print("FP =", fp)
    print("FN =", fn)
    print("TP =", tp)

    cm_df = pd.DataFrame(
        cm,
        index=["Actual 0", "Actual 1"],
        columns=["Pred 0", "Pred 1"]
    )
    print("\nConfusion Matrix Table:")
    print(cm_df)

    print("\nClassification Report:")
    print(classification_report(y_test, best_pred, zero_division=0))

    # simpan model per label
    safe_lab = lab.replace(" ", "_")
    joblib.dump(model, os.path.join(BASE_DIR, f"lr_{safe_lab}.pkl"))

    # simpan threshold
    threshold_dict[lab] = best_th

    # simpan ringkasan
    summary_rows.append({
        "label": lab,
        "best_threshold": best_th,
        "f1_binary": best_f1,
        "precision_binary": precision,
        "recall_binary": recall,
        "accuracy": acc,
        "tn": int(tn),
        "fp": int(fp),
        "fn": int(fn),
        "tp": int(tp),
        "positive_train_count": int(y_train.sum()),
        "positive_test_count": int(y_test.sum())
    })

    # simpan prediksi per sampel
    for i in range(len(test_df)):
        predictions[i][f"true_{lab}"] = int(y_test[i])
        predictions[i][f"prob_{lab}"] = float(y_prob[i])
        predictions[i][f"pred_{lab}"] = int(best_pred[i])
# Out:
# ============================================================
# Processing label: kepedulian
# Best threshold : 0.50
# F1 Score       : 0.9663
# Precision      : 1.0000
# Recall         : 0.9348
# Accuracy       : 0.9987
#
# Confusion Matrix:
# [[4558    0]
#  [   6   86]]
#
# TN = 4558
# FP = 0
# FN = 6
# TP = 86
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4558       0
# Actual 1       6      86
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4558
#            1       1.00      0.93      0.97        92
#
#     accuracy                           1.00      4650
#    macro avg       1.00      0.97      0.98      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: menyakiti
# Best threshold : 0.50
# F1 Score       : 0.8889
# Precision      : 0.9600
# Recall         : 0.8276
# Accuracy       : 0.9961
#
# Confusion Matrix:
# [[4560    3]
#  [  15   72]]
#
# TN = 4560
# FP = 3
# FN = 15
# TP = 72
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4560       3
# Actual 1      15      72
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4563
#            1       0.96      0.83      0.89        87
#
#     accuracy                           1.00      4650
#    macro avg       0.98      0.91      0.94      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: keadilan
# Best threshold : 0.45
# F1 Score       : 0.8514
# Precision      : 0.8514
# Recall         : 0.8514
# Accuracy       : 0.9953
#
# Confusion Matrix:
# [[4565   11]
#  [  11   63]]
#
# TN = 4565
# FP = 11
# FN = 11
# TP = 63
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4565      11
# Actual 1      11      63
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4576
#            1       0.85      0.85      0.85        74
#
#     accuracy                           1.00      4650
#    macro avg       0.92      0.92      0.92      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: kecurangan
# Best threshold : 0.50
# F1 Score       : 0.5000
# Precision      : 0.4737
# Recall         : 0.5294
# Accuracy       : 0.9961
#
# Confusion Matrix:
# [[4623   10]
#  [   8    9]]
#
# TN = 4623
# FP = 10
# FN = 8
# TP = 9
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4623      10
# Actual 1       8       9
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4633
#            1       0.47      0.53      0.50        17
#
#     accuracy                           1.00      4650
#    macro avg       0.74      0.76      0.75      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: loyalitas
# Best threshold : 0.55
# F1 Score       : 0.6538
# Precision      : 0.6800
# Recall         : 0.6296
# Accuracy       : 0.9961
#
# Confusion Matrix:
# [[4615    8]
#  [  10   17]]
#
# TN = 4615
# FP = 8
# FN = 10
# TP = 17
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4615       8
# Actual 1      10      17
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4623
#            1       0.68      0.63      0.65        27
#
#     accuracy                           1.00      4650
#    macro avg       0.84      0.81      0.83      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: pengkhianatan
# Best threshold : 0.45
# F1 Score       : 0.9870
# Precision      : 1.0000
# Recall         : 0.9744
# Accuracy       : 0.9998
#
# Confusion Matrix:
# [[4611    0]
#  [   1   38]]
#
# TN = 4611
# FP = 0
# FN = 1
# TP = 38
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4611       0
# Actual 1       1      38
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4611
#            1       1.00      0.97      0.99        39
#
#     accuracy                           1.00      4650
#    macro avg       1.00      0.99      0.99      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: otoritas
# Best threshold : 0.40
# F1 Score       : 0.9226
# Precision      : 0.8954
# Recall         : 0.9514
# Accuracy       : 0.9951
#
# Confusion Matrix:
# [[4490   16]
#  [   7  137]]
#
# TN = 4490
# FP = 16
# FN = 7
# TP = 137
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4490      16
# Actual 1       7     137
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4506
#            1       0.90      0.95      0.92       144
#
#     accuracy                           1.00      4650
#    macro avg       0.95      0.97      0.96      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: pembangkangan
# Best threshold : 0.40
# F1 Score       : 0.9231
# Precision      : 0.9474
# Recall         : 0.9000
# Accuracy       : 0.9994
#
# Confusion Matrix:
# [[4629    1]
#  [   2   18]]
#
# TN = 4629
# FP = 1
# FN = 2
# TP = 18
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4629       1
# Actual 1       2      18
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4630
#            1       0.95      0.90      0.92        20
#
#     accuracy                           1.00      4650
#    macro avg       0.97      0.95      0.96      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: kesucian
# Best threshold : 0.45
# F1 Score       : 0.9429
# Precision      : 0.9706
# Recall         : 0.9167
# Accuracy       : 0.9974
#
# Confusion Matrix:
# [[4539    3]
#  [   9   99]]
#
# TN = 4539
# FP = 3
# FN = 9
# TP = 99
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4539       3
# Actual 1       9      99
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4542
#            1       0.97      0.92      0.94       108
#
#     accuracy                           1.00      4650
#    macro avg       0.98      0.96      0.97      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: kemerosotan
# Best threshold : 0.40
# F1 Score       : 0.8000
# Precision      : 0.8421
# Recall         : 0.7619
# Accuracy       : 0.9983
#
# Confusion Matrix:
# [[4626    3]
#  [   5   16]]
#
# TN = 4626
# FP = 3
# FN = 5
# TP = 16
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4626       3
# Actual 1       5      16
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4629
#            1       0.84      0.76      0.80        21
#
#     accuracy                           1.00      4650
#    macro avg       0.92      0.88      0.90      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: kebebasan
# Best threshold : 0.35
# F1 Score       : 0.8571
# Precision      : 0.8182
# Recall         : 0.9000
# Accuracy       : 0.9987
#
# Confusion Matrix:
# [[4626    4]
#  [   2   18]]
#
# TN = 4626
# FP = 4
# FN = 2
# TP = 18
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4626       4
# Actual 1       2      18
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4630
#            1       0.82      0.90      0.86        20
#
#     accuracy                           1.00      4650
#    macro avg       0.91      0.95      0.93      4650
# weighted avg       1.00      1.00      1.00      4650
#
#
# ============================================================
# Processing label: penindasan
# Best threshold : 0.45
# F1 Score       : 0.9231
# Precision      : 1.0000
# Recall         : 0.8571
# Accuracy       : 0.9996
#
# Confusion Matrix:
# [[4636    0]
#  [   2   12]]
#
# TN = 4636
# FP = 0
# FN = 2
# TP = 12
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    4636       0
# Actual 1       2      12
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4636
#            1       1.00      0.86      0.92        14
#
#     accuracy                           1.00      4650
#    macro avg       1.00      0.93      0.96      4650
# weighted avg       1.00      1.00      1.00      4650

# %%
# =========================================================
# 5. SIMPAN HASIL
# =========================================================
summary_df = pd.DataFrame(summary_rows)
predictions_df = pd.DataFrame(predictions)

summary_df.to_csv(os.path.join(BASE_DIR, "lr_indonesia_summary_per_label.csv"), index=False)
predictions_df.to_csv(os.path.join(BASE_DIR, "lr_indonesia_predictions_12labels.csv"), index=False)

with open(os.path.join(BASE_DIR, "best_thresholds.json"), "w", encoding="utf-8") as f:
    json.dump(threshold_dict, f, ensure_ascii=False, indent=2)

print(f"\nSemua model dan hasil tersimpan di folder: {BASE_DIR}")
print("\nSummary:")
print(summary_df)
# Out:
# Semua model dan hasil tersimpan di folder: /content/drive/MyDrive/ML_MoralClassifier/LR_indonesia
#
# Summary:
#             label  best_threshold  f1_binary  precision_binary  recall_binary  \
# 0      kepedulian            0.50   0.966292          1.000000       0.934783
# 1       menyakiti            0.50   0.888889          0.960000       0.827586
# 2        keadilan            0.45   0.851351          0.851351       0.851351
# 3      kecurangan            0.50   0.500000          0.473684       0.529412
# 4       loyalitas            0.55   0.653846          0.680000       0.629630
# 5   pengkhianatan            0.45   0.987013          1.000000       0.974359
# 6        otoritas            0.40   0.922559          0.895425       0.951389
# 7   pembangkangan            0.40   0.923077          0.947368       0.900000
# 8        kesucian            0.45   0.942857          0.970588       0.916667
# 9     kemerosotan            0.40   0.800000          0.842105       0.761905
# 10      kebebasan            0.35   0.857143          0.818182       0.900000
# 11     penindasan            0.45   0.923077          1.000000       0.857143
#
#     accuracy    tn  fp  fn   tp  positive_train_count  positive_test_count
# 0   0.998710  4558   0   6   86                   370                   92
# 1   0.996129  4560   3  15   72                   349                   87
# 2   0.995269  4565  11  11   63                   294                   74
# 3   0.996129  4623  10   8    9                    68                   17
# 4   0.996129  4615   8  10   17                   107                   27
# 5   0.999785  4611   0   1   38                   156                   39
# 6   0.995054  4490  16   7  137                   575                  144
# 7   0.999355  4629   1   2   18                    80                   20
# 8   0.997419  4539   3   9   99                   434                  108
# 9   0.998280  4626   3   5   16                    82                   21
# 10  0.998710  4626   4   2   18                    82                   20
# 11  0.999570  4636   0   2   12                    58                   14
