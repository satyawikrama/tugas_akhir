# %%
import os
import json
import joblib
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    f1_score,
    precision_score,
    recall_score,
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

# %%
# =========================================================
# 1. LOAD DATA
# =========================================================
train_df = pd.read_csv("train_inggris.csv")
test_df = pd.read_csv("test_inggris.csv")

possible_labels = [
    "care", "harm",
    "fairness", "cheating",
    "loyalty", "betrayal",
    "authority", "subversion",
    "purity", "degradation",
    "liberty", "oppression"
]

# pastikan semua label ada di dataframe
for lab in possible_labels:
    if lab not in train_df.columns:
        raise ValueError(f"Label '{lab}' tidak ditemukan di train_df")
    if lab not in test_df.columns:
        raise ValueError(f"Label '{lab}' tidak ditemukan di test_df")

# teks
X_train_text = train_df["sentence"].astype(str)
X_test_text = test_df["sentence"].astype(str)

# %%
# =========================================================
# 2. TF-IDF VECTORIZATION
# =========================================================
vectorizer = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)

X_train = vectorizer.fit_transform(X_train_text)
X_test = vectorizer.transform(X_test_text)

print("Shape X_train:", X_train.shape)
print("Shape X_test :", X_test.shape)
# Out:
# Shape X_train: (9962, 10000)
# Shape X_test : (2491, 10000)

# %%
# =========================================================
# 3. SIAPKAN FOLDER SIMPAN
# =========================================================
from google.colab import drive
drive.mount('/content/drive')

BASE_DIR = "/content/drive/MyDrive/ML_MoralClassifier/LR_inggris"
os.makedirs(BASE_DIR, exist_ok=True)

print("Folder penyimpanan:", BASE_DIR)

# simpan vectorizer sekali saja
joblib.dump(vectorizer, os.path.join(BASE_DIR, "tfidf_vectorizer.pkl"))
# Out:
# Mounted at /content/drive
# Folder penyimpanan: /content/drive/MyDrive/ML_MoralClassifier/LR_inggris
# ['/content/drive/MyDrive/ML_MoralClassifier/LR_inggris/tfidf_vectorizer.pkl']

# %%
# =========================================================
# 4. TRAINING PER LABEL
# =========================================================
summary_rows = []
threshold_dict = {}
predictions = []

# inisialisasi dataframe prediksi
for i in range(len(test_df)):
    predictions.append({
        "sentence": test_df.iloc[i]["sentence"]
    })

for lab in possible_labels:
    print(f"\n{'='*60}")
    print(f"Processing label: {lab}")

    y_train = train_df[lab].astype(int).values
    y_test = test_df[lab].astype(int).values

    # model
    model = LogisticRegression(
        class_weight="balanced",
        max_iter=2000,
        random_state=42
    )

    # training
    model.fit(X_train, y_train)

    # probabilitas kelas positif
    y_prob = model.predict_proba(X_test)[:, 1]

    # threshold tuning
    best_f1 = -1
    best_th = 0.5
    best_pred = None

    for th in np.arange(0.05, 1.00, 0.05):
        temp_pred = (y_prob >= th).astype(int)
        temp_f1 = f1_score(y_test, temp_pred, average="binary", zero_division=0)

        if temp_f1 > best_f1:
            best_f1 = temp_f1
            best_th = float(th)
            best_pred = temp_pred.copy()

    # metrik final pakai best threshold
    precision = precision_score(y_test, best_pred, average="binary", zero_division=0)
    recall = recall_score(y_test, best_pred, average="binary", zero_division=0)
    acc = accuracy_score(y_test, best_pred)

    # confusion matrix
    cm = confusion_matrix(y_test, best_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    disp.plot(cmap="Blues")
    plt.title(f"Confusion Matrix - {lab}")
    plt.show()

    print(f"Best threshold : {best_th:.2f}")
    print(f"F1 Score       : {best_f1:.4f}")
    print(f"Precision      : {precision:.4f}")
    print(f"Recall         : {recall:.4f}")
    print(f"Accuracy       : {acc:.4f}")

    print("\nConfusion Matrix:")
    print(cm)

    print("\nTN =", tn)
    print("FP =", fp)
    print("FN =", fn)
    print("TP =", tp)

    cm_df = pd.DataFrame(
        cm,
        index=["Actual 0", "Actual 1"],
        columns=["Pred 0", "Pred 1"]
    )
    print("\nConfusion Matrix Table:")
    print(cm_df)

    print("\nClassification Report:")
    print(classification_report(y_test, best_pred, zero_division=0))

    # simpan model per label
    safe_lab = lab.replace(" ", "_")
    joblib.dump(model, os.path.join(BASE_DIR, f"nb_{safe_lab}.pkl"))

    # simpan threshold
    threshold_dict[lab] = best_th

    # simpan ringkasan
    summary_rows.append({
        "label": lab,
        "best_threshold": best_th,
        "f1_binary": best_f1,
        "precision_binary": precision,
        "recall_binary": recall,
        "accuracy": acc,
        "tn": int(tn),
        "fp": int(fp),
        "fn": int(fn),
        "tp": int(tp),
        "positive_train_count": int(y_train.sum()),
        "positive_test_count": int(y_test.sum())
    })

    # simpan prediksi per sampel
    for i in range(len(test_df)):
        predictions[i][f"true_{lab}"] = int(y_test[i])
        predictions[i][f"prob_{lab}"] = float(y_prob[i])
        predictions[i][f"pred_{lab}"] = int(best_pred[i])
# Out:
# ============================================================
# Processing label: care
# Best threshold : 0.45
# F1 Score       : 0.8071
# Precision      : 0.7847
# Recall         : 0.8309
# Accuracy       : 0.9783
#
# Confusion Matrix:
# [[2324   31]
#  [  23  113]]
#
# TN = 2324
# FP = 31
# FN = 23
# TP = 113
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2324      31
# Actual 1      23     113
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2355
#            1       0.78      0.83      0.81       136
#
#     accuracy                           0.98      2491
#    macro avg       0.89      0.91      0.90      2491
# weighted avg       0.98      0.98      0.98      2491
#
#
# ============================================================
# Processing label: harm
# Best threshold : 0.55
# F1 Score       : 0.7812
# Precision      : 0.8929
# Recall         : 0.6944
# Accuracy       : 0.9831
#
# Confusion Matrix:
# [[2374    9]
#  [  33   75]]
#
# TN = 2374
# FP = 9
# FN = 33
# TP = 75
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2374       9
# Actual 1      33      75
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2383
#            1       0.89      0.69      0.78       108
#
#     accuracy                           0.98      2491
#    macro avg       0.94      0.85      0.89      2491
# weighted avg       0.98      0.98      0.98      2491
#
#
# ============================================================
# Processing label: fairness
# Best threshold : 0.50
# F1 Score       : 0.8657
# Precision      : 0.9062
# Recall         : 0.8286
# Accuracy       : 0.9928
#
# Confusion Matrix:
# [[2415    6]
#  [  12   58]]
#
# TN = 2415
# FP = 6
# FN = 12
# TP = 58
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2415       6
# Actual 1      12      58
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2421
#            1       0.91      0.83      0.87        70
#
#     accuracy                           0.99      2491
#    macro avg       0.95      0.91      0.93      2491
# weighted avg       0.99      0.99      0.99      2491
#
#
# ============================================================
# Processing label: cheating
# Best threshold : 0.45
# F1 Score       : 0.4375
# Precision      : 0.5385
# Recall         : 0.3684
# Accuracy       : 0.9928
#
# Confusion Matrix:
# [[2466    6]
#  [  12    7]]
#
# TN = 2466
# FP = 6
# FN = 12
# TP = 7
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2466       6
# Actual 1      12       7
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2472
#            1       0.54      0.37      0.44        19
#
#     accuracy                           0.99      2491
#    macro avg       0.77      0.68      0.72      2491
# weighted avg       0.99      0.99      0.99      2491
#
#
# ============================================================
# Processing label: loyalty
# Best threshold : 0.55
# F1 Score       : 0.6923
# Precision      : 0.9474
# Recall         : 0.5455
# Accuracy       : 0.9936
#
# Confusion Matrix:
# [[2457    1]
#  [  15   18]]
#
# TN = 2457
# FP = 1
# FN = 15
# TP = 18
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2457       1
# Actual 1      15      18
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2458
#            1       0.95      0.55      0.69        33
#
#     accuracy                           0.99      2491
#    macro avg       0.97      0.77      0.84      2491
# weighted avg       0.99      0.99      0.99      2491
#
#
# ============================================================
# Processing label: betrayal
# Best threshold : 0.40
# F1 Score       : 0.3333
# Precision      : 0.3333
# Recall         : 0.3333
# Accuracy       : 0.9952
#
# Confusion Matrix:
# [[2476    6]
#  [   6    3]]
#
# TN = 2476
# FP = 6
# FN = 6
# TP = 3
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2476       6
# Actual 1       6       3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2482
#            1       0.33      0.33      0.33         9
#
#     accuracy                           1.00      2491
#    macro avg       0.67      0.67      0.67      2491
# weighted avg       1.00      1.00      1.00      2491
#
#
# ============================================================
# Processing label: authority
# Best threshold : 0.50
# F1 Score       : 0.9083
# Precision      : 0.9340
# Recall         : 0.8839
# Accuracy       : 0.9920
#
# Confusion Matrix:
# [[2372    7]
#  [  13   99]]
#
# TN = 2372
# FP = 7
# FN = 13
# TP = 99
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2372       7
# Actual 1      13      99
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2379
#            1       0.93      0.88      0.91       112
#
#     accuracy                           0.99      2491
#    macro avg       0.96      0.94      0.95      2491
# weighted avg       0.99      0.99      0.99      2491
#
#
# ============================================================
# Processing label: subversion
# Best threshold : 0.20
# F1 Score       : 0.3750
# Precision      : 0.3333
# Recall         : 0.4286
# Accuracy       : 0.9960
#
# Confusion Matrix:
# [[2478    6]
#  [   4    3]]
#
# TN = 2478
# FP = 6
# FN = 4
# TP = 3
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2478       6
# Actual 1       4       3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2484
#            1       0.33      0.43      0.38         7
#
#     accuracy                           1.00      2491
#    macro avg       0.67      0.71      0.69      2491
# weighted avg       1.00      1.00      1.00      2491
#
#
# ============================================================
# Processing label: purity
# Best threshold : 0.50
# F1 Score       : 0.6250
# Precision      : 0.8333
# Recall         : 0.5000
# Accuracy       : 0.9952
#
# Confusion Matrix:
# [[2469    2]
#  [  10   10]]
#
# TN = 2469
# FP = 2
# FN = 10
# TP = 10
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2469       2
# Actual 1      10      10
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2471
#            1       0.83      0.50      0.62        20
#
#     accuracy                           1.00      2491
#    macro avg       0.91      0.75      0.81      2491
# weighted avg       0.99      1.00      0.99      2491
#
#
# ============================================================
# Processing label: degradation
# Best threshold : 0.30
# F1 Score       : 0.6250
# Precision      : 0.6250
# Recall         : 0.6250
# Accuracy       : 0.9976
#
# Confusion Matrix:
# [[2480    3]
#  [   3    5]]
#
# TN = 2480
# FP = 3
# FN = 3
# TP = 5
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2480       3
# Actual 1       3       5
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2483
#            1       0.62      0.62      0.62         8
#
#     accuracy                           1.00      2491
#    macro avg       0.81      0.81      0.81      2491
# weighted avg       1.00      1.00      1.00      2491
#
#
# ============================================================
# Processing label: liberty
# Best threshold : 0.45
# F1 Score       : 0.8571
# Precision      : 0.9474
# Recall         : 0.7826
# Accuracy       : 0.9976
#
# Confusion Matrix:
# [[2467    1]
#  [   5   18]]
#
# TN = 2467
# FP = 1
# FN = 5
# TP = 18
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2467       1
# Actual 1       5      18
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2468
#            1       0.95      0.78      0.86        23
#
#     accuracy                           1.00      2491
#    macro avg       0.97      0.89      0.93      2491
# weighted avg       1.00      1.00      1.00      2491
#
#
# ============================================================
# Processing label: oppression
# Best threshold : 0.45
# F1 Score       : 0.6923
# Precision      : 0.9000
# Recall         : 0.5625
# Accuracy       : 0.9968
#
# Confusion Matrix:
# [[2474    1]
#  [   7    9]]
#
# TN = 2474
# FP = 1
# FN = 7
# TP = 9
#
# Confusion Matrix Table:
#           Pred 0  Pred 1
# Actual 0    2474       1
# Actual 1       7       9
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2475
#            1       0.90      0.56      0.69        16
#
#     accuracy                           1.00      2491
#    macro avg       0.95      0.78      0.85      2491
# weighted avg       1.00      1.00      1.00      2491

# %%
# =========================================================
# 5. SIMPAN HASIL
# =========================================================
summary_df = pd.DataFrame(summary_rows)
predictions_df = pd.DataFrame(predictions)

summary_df.to_csv(os.path.join(BASE_DIR, "lr_inggris_summary_per_label.csv"), index=False)
predictions_df.to_csv(os.path.join(BASE_DIR, "lr_inggris_predictions_12labels.csv"), index=False)

with open(os.path.join(BASE_DIR, "best_thresholds.json"), "w", encoding="utf-8") as f:
    json.dump(threshold_dict, f, ensure_ascii=False, indent=2)

print(f"\nSemua model dan hasil tersimpan di folder: {BASE_DIR}")
print("\nSummary:")
print(summary_df)
# Out:
# Semua model dan hasil tersimpan di folder: /content/drive/MyDrive/ML_MoralClassifier/LR_inggris
#
# Summary:
#           label  best_threshold  f1_binary  precision_binary  recall_binary  \
# 0          care            0.45   0.807143          0.784722       0.830882
# 1          harm            0.55   0.781250          0.892857       0.694444
# 2      fairness            0.50   0.865672          0.906250       0.828571
# 3      cheating            0.45   0.437500          0.538462       0.368421
# 4       loyalty            0.55   0.692308          0.947368       0.545455
# 5      betrayal            0.40   0.333333          0.333333       0.333333
# 6     authority            0.50   0.908257          0.933962       0.883929
# 7    subversion            0.20   0.375000          0.333333       0.428571
# 8        purity            0.50   0.625000          0.833333       0.500000
# 9   degradation            0.30   0.625000          0.625000       0.625000
# 10      liberty            0.45   0.857143          0.947368       0.782609
# 11   oppression            0.45   0.692308          0.900000       0.562500
#
#     accuracy    tn  fp  fn   tp  positive_train_count  positive_test_count
# 0   0.978322  2324  31  23  113                   546                  136
# 1   0.983139  2374   9  33   75                   430                  108
# 2   0.992774  2415   6  12   58                   282                   70
# 3   0.992774  2466   6  12    7                    75                   19
# 4   0.993577  2457   1  15   18                   131                   33
# 5   0.995183  2476   6   6    3                    37                    9
# 6   0.991971  2372   7  13   99                   450                  112
# 7   0.995986  2478   6   4    3                    28                    7
# 8   0.995183  2469   2  10   10                    81                   20
# 9   0.997591  2480   3   3    5                    34                    8
# 10  0.997591  2467   1   5   18                    93                   23
# 11  0.996788  2474   1   7    9                    65                   16
